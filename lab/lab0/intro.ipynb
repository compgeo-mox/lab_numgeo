# %% [markdown]
# # Introduction to Python programming

# %% [markdown]
# ## Python program files

# %% [markdown]
# * Python code is usually stored in text files with the file ending "`.py`":
#
#         myprogram.py
#
# * Every line in a Python program file is assumed to be a Python statement, or part thereof.
#
#     * The only exception is comment lines, which start with the character `#` (optionally preceded by an arbitrary number of white-space characters, i.e., tabs or spaces). Comment lines are usually ignored by the Python interpreter.
#
#
# * To run our Python program from the command line we use:
#
#         $ python myprogram.py
#
# * On UNIX systems it is common to define the path to the interpreter on the first line of the program (note that this is a comment line as far as the Python interpreter is concerned):
#
#         #!/usr/bin/env python
#
#   If we do, and if we additionally set the file script to be executable, we can run the program like this:
#
#         $ myprogram.py

# %% [markdown]
# ## Modules

# %% [markdown]
# Most of the functionality in Python is provided by *modules*. The Python Standard Library is a large collection of modules that provides *cross-platform* implementations of common facilities such as access to the operating system, file I/O, string management, network communication, and much more.

# %% [markdown]
# ### References

# %% [markdown]
#  * The Python Language Reference: http://docs.python.org/3/reference/index.html
#  * The Python Standard Library: http://docs.python.org/3/library/
#
# To use a module in a Python program it first has to be imported. A module can be imported using the `import` statement. For example, to import the module `math` and call it `mt`, which contains many standard mathematical functions, we can do:

# %%
import math as mt

# %% [markdown]
# This includes the whole module and makes it available for use later in the program. For example, we can do:

# %%
x = mt.cos(2 * mt.pi)

print(x)

# %% [markdown]
# Alternatively, we can chose to import all symbols (functions and variables) in a module to the current namespace (so that we don't need to use the prefix "`math.`" every time we use something from the `math` module:

# %%
from math import *

x = cos(2 * pi)

print(x)

# %% [markdown]
# This pattern can be very convenient, but in large programs that include many modules it is often a good idea to keep the symbols from each module in their own namespaces, by using the `import math` pattern. This would eliminate potentially confusing problems with name space collisions.
#
# As a third alternative, we can chose to import only a few selected symbols from a module by explicitly listing which ones we want to import instead of using the wildcard character `*`:

# %%
from math import cos, pi

x = sin(2 * pi)

print(x)

# %% [markdown]
# ### Looking at what a module contains, and its documentation

# %% [markdown]
# Once a module is imported, we can list the symbols it provides using the `dir` function:

# %%
import math

print(dir(math))

# %% [markdown]
# And using the function `help` we can get a description of each function (almost .. not all functions have docstrings, as they are technically called, but the vast majority of functions are documented this way).

# %%
help(math.log)

# %% [markdown]
# Let's also try the natural logarithm.

# %%
math.log(10)

# %% [markdown]
# And the logarithm with a different base.

# %%
math.log(10, 2)

# %% [markdown]
# We can look at the full documentation for the `math` module.

# %%
help(math)

# %% [markdown]
# We can also use the `help` function directly on modules: Try
#
#     help(math)
#
# Some very useful modules form the Python standard library are `os`, `sys`, `math`, `shutil`, `re`, `subprocess`, `multiprocessing`, `threading`.
#
# A complete list of standard modules is available at http://docs.python.org/3/library/.

# %% [markdown]
# ## Variables and types

# %% [markdown]
# ### Symbol names

# %% [markdown]
# Variable names in Python can contain alphanumerical characters `a-z`, `A-Z`, `0-9` and some special characters such as `_`. Normal variable names must start with a letter.
#
# By convention, variable names start with a lower-case letter, and Class names start with a capital letter.
#
# In addition, there are a number of Python keywords that cannot be used as variable names. These keywords are:
#
#     and, as, assert, break, class, continue, def, del, elif, else, except,
#     exec, finally, for, from, global, if, import, in, is, lambda, not, or,
#     pass, print, raise, return, try, while, with, yield
#
# **Note:** Be aware of the keyword `lambda`, which could easily be a natural variable name in a scientific program. But being a keyword, it cannot be used as a variable name.
#
# **Note:** Be careful in using `range` as variable: it is allowed but it will erase the `range` command!

# %% [markdown]
# ### Assignment

# %% [markdown]
# The assignment operator in Python is `=`. Python is a <font color='red'> dynamically typed language</font>, so we do not need to specify the type of a variable when we create one.
#
# Assigning a value to a new variable creates the variable:

# %%
# variable assignments
x = 1
my_variable = 12.2

# %% [markdown]
# Although not explicitly specified, a variable does have a type associated with it. The type is derived from the value that was assigned to it.

# %%
type(x)

# %% [markdown]
# If we assign a new value to a variable, its type can change.

# %%
x = 1.1

# %% [markdown]
# Let's check the type.

# %%
type(x)

# %% [markdown]
# If we try to use a variable that has not yet been defined we get an `NameError`:

# %%
print(y)

# %% [markdown]
# ### Fundamental types

# %%
# integers
x = 1
type(x)

# %% [markdown]
# Let's also check a floating-point number.

# %%
# float
x = 1.0
type(x)

# %% [markdown]
# And a boolean.

# %%
# boolean
b1 = True
b2 = False

type(b1)

# %% [markdown]
# And a complex number.

# %%
# complex numbers: note the use of `j` to specify the imaginary part
x = 1.0 - 1.0j
type(x)

# %% [markdown]
# Let's print it.

# %%
print(x)

# %% [markdown]
# We can also access its real and imaginary parts separately.

# %%
print(x.real, x.imag)

# %% [markdown]
# ### Type utility functions

# %% [markdown]
# The module `types` contains a number of type name definitions that can be used to test if variables are of certain types:

# %%
import types

# print all types defined in the `types` module
print(dir(types))

# %% [markdown]
# We can check if the type is exactly `float`.

# %%
x = 1.0

# check if the variable x is a float
type(x) is float

# %% [markdown]
# Or exactly `int`.

# %%
# check if the variable x is an int
type(x) is int

# %% [markdown]
# We can also use the `isinstance` method for testing types of variables:

# %%
isinstance(x, float)

# %% [markdown]
# ### Type casting

# %%
x = 1.9

print(x, type(x))

# %% [markdown]
# Let's cast it to an integer.

# %%
x = int(x)

print(x, type(x))

# %% [markdown]
# And then to a complex number.

# %%
z = complex(x)

print(z, type(z))

# %% [markdown]
# Let's try casting it back to a float.

# %%
x = float(z)

# %% [markdown]
# Complex variables cannot be cast to floats or integers. We need to use `z.real` or `z.imag` to extract the part of the complex number we want:

# %%
y = bool(z.real)

print(z.real, " -> ", y, type(y))

y = bool(z.imag)

print(z.imag, " -> ", y, type(y))

# %% [markdown]
# ## Operators and comparisons

# %% [markdown]
# Most operators and comparisons in Python work as one would expect:
#
# * Arithmetic operators `+`, `-`, `*`, `/`, `//` (integer division), '**' power

# %%
1 + 2, 1 - 2, 1 * 2, 1 / 2, 10 % 3

# %% [markdown]
# Let's try the basic arithmetic operators.

# %%
1.0 + 2, 1.0 - 2.0, 1.0 * 2.0, 1.0 / 2.0

# %% [markdown]
# We can also use integer division on floats.

# %%
# Integer division of float numbers
3.0 // 2.0

# %% [markdown]
# Python has arbitrary-precision integers, so large powers don't overflow.

# %%
# Note! The power operators in python isn't ^, but **type
type(2**128)

# %% [markdown]
# Note: The `/` operator always performs a floating point division in Python 3.x.
# This is not true in Python 2.x, where the result of `/` is always an integer if the operands are integers.
# To be more specific, `1/2 = 0.5` (`float`) in Python 3.x, and `1/2 = 0` (`int`) in Python 2.x (but `1.0/2 = 0.5` in Python 2.x).

# %% [markdown]
# * The boolean operators are spelled out as the words `and`, `not`, `or`.

# %%
True and False

# %% [markdown]
# Let's try the `not` operator.

# %%
not False

# %% [markdown]
# And `or`.

# %%
True or False

# %% [markdown]
# * Comparison operators `>`, `<`, `>=` (greater or equal), `<=` (less or equal), `==` equality, `!=` not equal and `is` identical.

# %%
2 > 1, 2 < 1

# %% [markdown]
# Let's try some comparisons.

# %%
2 > 2, 2 < 2

# %% [markdown]
# And the `>=`/`<=` operators.

# %%
2 >= 2, 2 <= 2

# %% [markdown]
# We can also chain comparisons.

# %%
x = 10
1 < x < 20

# %% [markdown]
# Python also has a `None` type.

# %%
a = None
type(a)

# %% [markdown]
# We can check if two lists are equal.

# %%
# equality
[1, 2] == [1, 2]

# %% [markdown]
# Let's check if two lists with the same content are identical objects.

# %%
# objects identical?
l1 = l2 = [1, 2]
# l2 = l1
l3 = [1, 2]
l1 == l3

# %% [markdown]
# Let's also compare `l1` and `l3` for identity.

# %%
# objects identical?
l1 is l3

# %% [markdown]
# And `l1` with `l2`.

# %%
l1 is l2

# %% [markdown]
# Since `l1` and `l2` refer to the same list, modifying one affects the other.

# %%
l2[1] = 5
print(l1)

# %% [markdown]
# We can use `is` to check if a variable is `None`.

# %%
x = 10
y = None

(x is None, y is None)

# %% [markdown]
# Small integers are cached by Python, so `is` may (misleadingly) also work for them.

# %%
x = 1
x is 1

# %% [markdown]
# ## Compound types: Strings, List and Dictionaries

# %% [markdown]
# ### Strings

# %% [markdown]
# Strings are the variable type that is used for storing text messages.

# %%
s = "Hello world"
type(s)

# %% [markdown]
# Let's check the length of the string.

# %%
# length of the string: the number of characters
len(s)

# %% [markdown]
# We can also replace a substring.

# %%
# replace a substring in a string with something else
s2 = s.replace("world", "test")
s1 = s2
s1 = s1.replace("test", "world")
print(s1)
print(s2)

# %% [markdown]
# We can index a character in a string using `[]`:

# %%
s[0], s[1], s[len(s) - 1]

# %% [markdown]
# **Warning MATLAB users:** Indexing start at 0!
#
# We can extract a part of a string using the syntax `[start:stop]`, which extracts characters between index `start` and `stop` -1 (the character at index `stop` is not included):

# %%
s[0:10]

# %% [markdown]
# We can slice the string.

# %%
s[:6]

# %% [markdown]
# If we omit either (or both) of `start` or `stop` from `[start:stop]`, the default is the beginning and the end of the string, respectively:

# %%
s[:]

# %% [markdown]
# Or take the last few characters.

# %%
s[-5:]

# %% [markdown]
# We can also take a full copy via slicing.

# %%
s[:]

# %% [markdown]
# We can also define the step size using the syntax `[start:end:step]` (the default value for `step` is 1, as we saw above):

# %%
s[::-1]

# %% [markdown]
# Let's build a new string by combining slices.

# %%
s1 = s[0:2] + "x" + s[3:]
print(s1)

# %% [markdown]
# This technique is called *slicing*. Read more about the syntax here:
# https://docs.python.org/3/library/functions.html?highlight=slice#slice

# %% [markdown]
# Python has a very rich set of functions for text processing. See for example http://docs.python.org/3/library/string.html for more information.

# %% [markdown]
# #### String formatting examples

# %%
print("str1", "str2", "str3")  # The print statement concatenates strings with a space

# %% [markdown]
# The `print` function converts all its arguments to strings.

# %%
print("str1", 1.0, False, -1j)  # The print statements converts all arguments to strings

# %% [markdown]
# Strings added with `+` are concatenated without a space.

# %%
print("str1" + "str2" + "str3")  # strings added with + are concatenated without space

# %% [markdown]
# We can use C-style string formatting.

# %%
print("value = %d" % 1.0)  # we can use C-style string formatting

# %% [markdown]
# Let's format multiple values.

# %%
# this formatting creates a string
s2 = "value1 = %.2f. value2 = %d" % (1.5, 3.1415)

print(s2)

# %% [markdown]
# Or use the more modern `.format()` method.

# %%
# alternative, more intuitive way of formatting a string
s3 = "value1 = {y} value2 = {x:d}".format(x=int(3.1415), y=1.5)

print(s3)

# %% [markdown]
# ### List

# %% [markdown]
# Lists are very similar to strings, except that each element can be of any type.
#
# The syntax for creating lists in Python is `[...]`:

# %%
l = [1, 2, 3, 4, "a"]

print(type(l))
print(l)

# %% [markdown]
# We can use the same slicing techniques to manipulate lists as we could use on strings:

# %%
print(l)

print(l[1:3])

print(l[::2])

# %% [markdown]
# **Warning MATLAB users:** Indexing starts at 0!

# %%
l1 = l
l[0] = 2
print(l)
print(l1)

# %% [markdown]
# Elements in a list do not all have to be of the same type:

# %%
l = [1, "a", 1.0, 1 - 1j]

print(l)

# %% [markdown]
# Python lists can be inhomogeneous and arbitrarily nested:

# %%
nested_list = [1, [2, [3, [4, [5]]]]]

nested_list

# %% [markdown]
# Let's see what happens when we append a copy of the list to itself.

# %%
x = [
    1,
]
x.append(x[:])
print(x)
print(x[0])

# %% [markdown]
# Lists play a very important role in Python. For example they are used in loops and other flow control structures (discussed below). There are a number of convenient functions for generating lists of various types, for example the `range` function:

# %%
start = 10
stop = 30
step = 2

range(start, stop, step)
list(range(start, stop, step))

# %% [markdown]
# In Python 3, `range` returns an iterator rather than a list.

# %%
# in python 3 range generates an iterator, which can be converted to a list using 'list(...)'.
# It has no effect in python 2
list(range(start, stop, step))

# %% [markdown]
# We can still convert it to a list.

# %%
list(range(-10, 10))

# %% [markdown]
# Let's define a string.

# %%
s = "Hello world"

# %% [markdown]
# We can convert a string to a list of its characters.

# %%
# convert a string to a list by type casting:
s2 = list(s)

s2

# %% [markdown]
# We can sort the list.

# %%
# sorting lists
s2.sort()

print(s2)

# %% [markdown]
# #### Adding, inserting, modifying, and removing elements from lists

# %%
# create a new empty list
l = []

# add an elements using `append`
l.append("A")
l.append("d")
l.append("d")

print(l)

# %% [markdown]
# We can modify lists by assigning new values to elements in the list. In technical jargon, **lists are mutable**.

# %%
l[1] = "p"
l[2] = "p"

print(l)

# %% [markdown]
# We can also assign to a slice.

# %%
l[1:3] = ["d", "d"]

print(l)

# %% [markdown]
# Insert an element at a specific index using `insert`

# %%
l.insert(0, "i")
l.insert(1, "n")
l.insert(2, "s")
l.insert(3, "e")
l.insert(4, "r")
l.insert(5, "t")

print(l)

# %% [markdown]
# Remove first element with specific value using 'remove'

# %%
l.remove("d")

print(l)

# %% [markdown]
# Let's check the result.

# %%
print(l)

# %% [markdown]
# Remove an element at a specific location using `del`:

# %%
del l[3]
del l[4]

print(l)

# %% [markdown]
# See `help(list)` for more details, or read the online documentation

# %%
help(list)

# %% [markdown]
# ### Tuples

# %% [markdown]
# Tuples are like lists, except that they cannot be modified once created, that is they are <font color='red'>immutable</font>.
#
# In Python, tuples are created using the syntax `(..., ..., ...)`, or even `..., ...`:

# %%
point = (10, 20)

print(point, type(point))

# %% [markdown]
# We can also create a tuple without parentheses.

# %%
point = 10, 20

print(point, type(point))

# %% [markdown]
# We can unpack a tuple by assigning it to a comma-separated list of variables:

# %%
x, y = point

print("x =", x)
print("y =", y)

# %% [markdown]
# If we try to assign a new value to an element in a tuple we get an error:

# %%
point[0] = 22

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionaries are also like lists, except that each element is a key-value pair. The syntax for dictionaries is `{key1 : value1, ...}`:

# %%
params = {
    "parameter1": 1.0,
    "parameter2": 2.0,
    "parameter3": 3.0,
    5: 4.0,
}

print(type(params))
print(params)

# %% [markdown]
# Let's try accessing a key that doesn't exist yet.

# %%
print("The value of parameter 1 is " + str(params["parameter4"]))
print("parameter2 = " + str(params["parameter2"]))
print("parameter3 = " + str(params["parameter3"]))

# %% [markdown]
# Let's add the missing key and try again.

# %%
params["parameter1"] = "A"
params["parameter2"] = "B"

# add a new entry
params["parameter4"] = "D"

print("parameter1 = " + str(params["parameter1"]))
print("parameter2 = " + str(params["parameter2"]))
print("parameter3 = " + str(params["parameter3"]))
print("parameter4 = " + str(params["parameter4"]))
print("5 = " + str(params[5]))

# %% [markdown]
# ## Control Flow

# %% [markdown]
# ### Conditional statements: if, elif, else

# %% [markdown]
# The Python syntax for conditional execution of code uses the keywords `if`, `elif` (else if), `else`:

# %%
statement1 = False
statement2 = False

if statement1:
    print("statement1 is True")
    print("123")
    print("abc")

elif statement2:
    print("statement2 is True")

else:
    print("statement1 and statement2 are False")

    print("Ciao")

# %% [markdown]
# For the first time, here we encounted a peculiar and unusual aspect of the Python programming language: Program blocks are defined by their indentation level.
#
# In Python, the extent of a code block is defined by the <font color='red'>indentation level</font> (usually a tab or say four white spaces). This means that we have to be careful to indent our code correctly, or else we will get syntax errors.

# %% [markdown]
# #### Examples:

# %%
statement1 = statement2 = True

if statement1:
    if statement2:
        print("both statement1 and statement2 are True")

# %% [markdown]
# Let's see what happens with incorrect indentation.

# %%
# Bad indentation!
if statement1:
    if statement2:
    print("both statement1 and statement2 are True")  # this line is not properly indented

# %% [markdown]
# Let's define a conditional statement.

# %%
statement1 = False

if statement1:
    print("printed if statement1 is True")

print("still inside the if block")

# %% [markdown]
# Let's check the indentation again.

# %%
if statement1:
    print("printed if statement1 is True")

print("now outside the if block")

# %% [markdown]
# ## Loops

# %% [markdown]
# In Python, loops can be programmed in a number of different ways. The most common is the `for` loop, which is used together with iterable objects, such as lists. The basic syntax is:

# %% [markdown]
# ### **`for` loops**:

# %%
l = [1, 2, "A"]
print(len(l))
list(range(len(l)))

# %% [markdown]
# We can iterate over a list using its indices.

# %%
for i in range(len(l)):
    x = l[i]
    print(x)

# %% [markdown]
# Or more directly, over its elements.

# %%
for x in l:
    print(x)

# %% [markdown]
# We can pair up two lists with `zip`.

# %%
l1 = [1, 2, 3]
l2 = ["a", "b", "c"]
ll = zip(l1, l2)
print(ll)

# %% [markdown]
# We can iterate over the pairs, together with their index, using `enumerate`.

# %%
for i, (x, y) in enumerate(ll):
    print(i, x, y)

# %% [markdown]
# The `for` loop iterates over the elements of the supplied list, and executes the containing block once for each element. Any kind of list can be used in the `for` loop. For example:

# %%
for x in range(4):  # by default range start at 0
    print(x)

# %% [markdown]
# Note: `range(4)` does not include 4 !

# %%
for x in range(-3, 3):
    print(x)

# %% [markdown]
# We can iterate over any list.

# %%
for word in ["scientific", "computing", "with", "python"]:
    print(word)

# %% [markdown]
# To iterate over key-value pairs of a dictionary:

# %%
params = {
    "parameter1": 1.0,
    "parameter2": 2.0,
    "parameter3": 3.0,
    5: 4.0,
}

# print(params.items())

for key, value in params.items():
    print(str(key) + " = " + str(value))

# %% [markdown]
# Sometimes it is useful to have access to the indices of the values when iterating over a list. We can use the `enumerate` function for this:

# %%
for idx, x in enumerate(range(-3, 3)):
    print(idx, x)

# %% [markdown]
# We can use `break` to exit a loop early.

# %%
for i in range(10):
    print(i)
    if i == 4:
        break
    else:
        print("else")
print(i)

# %% [markdown]
# ### List comprehensions: creating lists using `for` loops:

# %% [markdown]
# A convenient and compact way to initialize lists:

# %%
import math as mt

l1 = (x**2 + mt.sin(x) for x in range(0, 5))

print(type(l1))
print(list(l1))

# %% [markdown]
# ### `while` loops:

# %%
i = 1

while i < 5:
    print(i)

    i += 1

print("done")

# %% [markdown]
# Note that the `print("done")` statement is not part of the `while` loop body because of the difference in indentation.

# %% [markdown]
# **Exercise 1.** Let us compute the machine epsilon `eps` using `while`. Remember that the definition of $\epsilon$ is the smallest number such that $1\neq 1+\epsilon$.

# %%
e = 1.0
while 1 + e != 1:
    e = e / 2

print(e)

# %% [markdown]
# We can also compute the machine epsilon using NumPy.

# %%
import numpy as np

print(np.finfo(float).eps)

# %% [markdown]
# See https://docs.scipy.org/doc/numpy-1.14.1/reference/generated/numpy.MachAr.html

# %% [markdown]
# ## Functions

# %% [markdown]
# A function in Python is defined using the keyword `def`, followed by a function name, a signature within parentheses `()`, and a colon `:`. The following code, with one additional level of indentation, is the function body.

# %%
def func0():
    print("test")

# %% [markdown]
# Let's call the function.

# %%
func0()

# %% [markdown]
# Optionally, but highly recommended, we can define a so called "docstring", which is a description of the function's purpose and behavior. The docstring should follow directly after the function definition, before the code in the function body.

# %%
def func1(s):
    """
    Print a string 's' and tell how many characters it has
    """

    print(s + " has " + str(len(s)) + " characters")

# %% [markdown]
# We can look at the docstring.

# %%
help(func1)

# %% [markdown]
# Let's call the function.

# %%
func1("test")

# %% [markdown]
# Functions that returns a value use the `return` keyword:

# %%
def square(x):
    """
    Return the square of x.
    """
    return x**2

# %% [markdown]
# We can also check its docstring.

# %%
help(square)

# %% [markdown]
# Let's call it.

# %%
square(4)

# %% [markdown]
# We can return multiple values from a function using tuples:

# %%
def powers(x):
    """
    Return a few powers of x.
    """
    return x**2, x**3, x**4

# %% [markdown]
# Let's call the function.

# %%
powers(3)

# %% [markdown]
# We can unpack the returned tuple.

# %%
x2, x3, x4 = powers(3)

print(x3)

# %% [markdown]
# ### Default argument and keyword arguments

# %% [markdown]
# In a definition of a function, we can give default values to the arguments the function takes:

# %%
def myfunc(x, p=2, debug=False):
    if debug:
        print("evaluating myfunc for x = " + str(x) + " using exponent p = " + str(p))
    return x**p

# %% [markdown]
# If we don't provide a value of the `debug` argument when calling the function `myfunc` it defaults to the value provided in the function definition:

# %%
myfunc(5)

# %% [markdown]
# Let's call it with the optional argument.

# %%
myfunc(5, debug=True)

# %% [markdown]
# If we explicitly list the name of the arguments in the function calls, they do not need to come in the same order as in the function definition. This is called *keyword* arguments, and is often very useful in functions that takes a lot of optional arguments.

# %%
myfunc(3, debug=True, p=7)

# %% [markdown]
# ### Unnamed functions (lambda function)

# %% [markdown]
# In Python we can also create unnamed functions, using the `lambda` keyword:

# %%
f1 = lambda x: x**2

# is equivalent to


def f2(x):
    return x**2

# %% [markdown]
# Let's call both functions.

# %%
f1(2), f2(2)

# %% [markdown]
# This technique is useful for example when we want to pass a simple function as an argument to another function, like this:

# %%
# map is a built-in python function
map(lambda x, y: x + y, range(-3, 4))

# %% [markdown]
# In Python 3, we can convert the map iterator to an explicit list.

# %%
# in python 3 we can use `list(...)` to convert the iterator to an explicit list
list(map(lambda x: x**2, range(-3, 4)))

# %% [markdown]
# We can also look at the documentation for `map`.

# %%
help(map)

# %% [markdown]
# We can use a regular function instead of a lambda.

# %%
def calculateSquare(n):
    return n * n


numbers = (1, 2, 3, 4)
result = map(calculateSquare, numbers)
print(result)

# converting map object to
numbersSquare = list(result)
print(numbersSquare)

# %% [markdown]
# Let's also look at the documentation for `set`.

# %%
help(set)

# %% [markdown]
# **Exercise 1.** Write a Python function to print the even numbers from a given list.
#
# **Exercise 2.** Write a Python function to multiply all the numbers in a list.
#
# **Exercise 3.** Write a Python function that prints out the first n rows of Pascal's triangle.
#
# **Exercise 4.** Write a Python function that checks if a given number is prime.

# %% [markdown]
# **Exercise 5.** Write a Python function for computing the factorial of a given integer number. Remember that the factorial is defined only for positive integer number and that the factorial of 0 is 1.

# %% [markdown]
# ### The `__main__` variable

# %%
def main():
    print("Ciao")


print("Ops!!!")
# print(__name__)

# %% [markdown]
# Let's see this pattern in action.

# %%
def main():
    print("Ciao")


if __name__ == "__main__":
    main()

print("Ops!")

# %% [markdown]
# - When the Python interpreter reads a source file, it will execute all the code found in it.
# - When Python runs the source file as the main program, it sets the special variable `__name__` to the value `"__main__"`.
# - When you execute the main function, it will then read the `if` statement and check whether `__name__` equals `"__main__"`.
# - In Python, `if __name__ == "__main__":` lets you run a file either as a reusable module or as a standalone program.
